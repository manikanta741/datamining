# %% [markdown]
# <a href="https://colab.research.google.com/github/manikanta741/datamining/blob/main/hist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

import numpy as  np
x=np.array([10,9,5,23,44,57])
plt.hist(x,bins=3,color='green',rwidth=0.95,label="hist")
# Out:
# (array([3., 1., 2.]),
#  array([ 5.        , 22.33333333, 39.66666667, 57.        ]),
#  <BarContainer object of 3 artists>)
